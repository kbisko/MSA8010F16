# %%
import pandas as pd
import math as math
movie=pd.read_table('/home/data/MSA8010/msa8010f16t02/movie_v4.csv', sep=',')

# %%
movie
# Out:
#       Unnamed: 0  color  director_name  num_critic_for_reviews  duration  \
# 0              0      0              0                   723.0     178.0
# 1              1      0              1                   302.0     169.0
# 2              2      0              2                   602.0     148.0
# 3              3      0              3                   813.0     164.0
# 4              5      0              4                   462.0     132.0
# 5              6      0              5                   392.0     156.0
# 6              7      0              6                   324.0     100.0
# 7              8      0              7                   635.0     141.0
# 8              9      0              8                   375.0     153.0
# 9             10      0              9                   673.0     183.0
# 10            11      0             10                   434.0     169.0
# 11            12      0             11                   403.0     106.0
# ...

# %%
gen=movie.loc[:,["movie_title","genres"]].groupby('movie_title').genres.apply(lambda x: pd.DataFrame(x.str.split('|').tolist())).reset_index().drop('level_1', axis=1)
gen
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-ba18e18aa2d5> in <module>()
# ----> 1 gen=movie.loc[:,["movie_title","genres"]].groupby('movie_title').genres.apply(lambda x: pd.DataFrame(x.str.split('|').tolist())).reset_index().drop('level_1', axis=1)
#       2 gen
#
# /usr/lib64/python3.4/site-packages/pandas/core/groupby.py in apply(self, func, *args, **kwargs)
#     649         # ignore SettingWithCopy here in case the user mutates
#     650         with option_context('mode.chained_assignment', None):
# --> 651             return self._python_apply_general(f)
#     652
#     653     def _python_apply_general(self, f):
#
# /usr/lib64/python3.4/site-packages/pandas/core/groupby.py in _python_apply_general(self, f)
#     653     def _python_apply_general(self, f):
#     654         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# ...

# %%
genre_list=movie['genres'].apply(lambda x: x.split('|'))
flat_gen_list=set()
for x in genre_list:
    for y in x:
        flat_gen_list.add(y)
flat_gen_list
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Film-Noir',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Thriller',
#  'War',
#  'Western'}

# %%
genre_list_final=[]
for y in range(0,len(gen)):
    for x in genre_list:
        for i in len(gen.):
            if gen.iloc[y,i]=='NaN':
                z = 0
                break
            elif gen.iloc[y,i] == x: 
                z = 1
                break
            else:
                z = 0
                i+1
        genre_list_final.append([gen.loc[y,'movie_title'], x, z])

genre_list_final
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-436b17f3c871> in <module>()
#      12                 z = 0
#      13                 i+1
# ---> 14         genre_list_final.append([gen.loc[y,'movie_title'], x, z])
#      15
#      16 genre_list_final
#
# /usr/lib64/python3.4/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1292
#    1293         if type(key) is tuple:
# -> 1294             return self._getitem_tuple(key)
#    1295         else:
#    1296             return self._getitem_axis(key, axis=0)
#
# /usr/lib64/python3.4/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     782     def _getitem_tuple(self, tup):
#     783         try:
# --> 784             return self._getitem_lowerdim(tup)
#     785         except IndexingError:
#     786             pass
#
# ...

# %%
3:52
